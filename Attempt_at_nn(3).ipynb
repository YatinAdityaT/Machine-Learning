# %% [markdown]
# # Data pre-processing

# %%
import numpy as np
import pandas as pd

# %%
iris =  pd.read_csv("/home/yatin/Downloads/IRIS.csv")
iris = iris.sample(frac=1).reset_index(drop=True) # Shuffle

# %%
iris.shape
# Out:
# (150, 5)

# %%
X = iris[["sepal_length","sepal_width","petal_length","petal_width"]]
X = np.array(X)
X.shape
# Out:
# (150, 4)

# %%
from sklearn.preprocessing import OneHotEncoder
one_hot_encoder = OneHotEncoder(sparse=False)

Y = iris.species
# print(Y)
Y = one_hot_encoder.fit_transform(np.array(Y).reshape(-1, 1))
Y[0:5]
print(Y.shape)
# Out:
# (150, 3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20)
X_train=X_train.T
Y_train=Y_train.T
X_test=X_test.T
Y_test=Y_test.T
print("X_train.shape",X_train.shape,"\nY_train.shape",Y_train.shape,"\nX_test",X_test.shape,"\nY_test",Y_test.shape)
# Out:
# X_train.shape (4, 120)
# Y_train.shape (3, 120)
# X_test (4, 30)
# Y_test (3, 30)

# %% [markdown]
# # Functions

# %%
def initialize_parameters(layers_dims, print_shapes = False):
    
    L = len(layers_dims)
    parameters ={}
    
    for i in range(1,L) :
        parameters['W'+ str(i)] = np.random.rand(layers_dims[i],layers_dims[i-1])*0.01
        parameters['b'+ str(i)] = np.zeros((layers_dims[i],1))
        
    if print_shapes :
        initialize_parameters_print_shapes(parameters)
                
    return parameters

# %%
def initialize_parameters_print_shapes(parameters):
    print('initialised:\n')
    for i in range(1,L):
        print('W'+ str(i),parameters['W'+ str(i)].shape)
        print('b'+ str(i),parameters['b'+ str(i)].shape)
    print('--------------------------------------------')

# %%
# def relu(Z):
#     A = np.maximum(Z,0,Z)
#     return A

# def sigmoid(Z):
#     A = 1/(1+np.exp(-Z))
#     return A

# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
def forward_propogation(X,parameters,layers_dims,print_para = False):
    
    L = len(layers_dims)
    A_prev = X
    
    for i in range(1,L):
        parameters ['Z'+ str(i)] = np.dot(parameters ['W'+ str(i)],A_prev) + parameters ['b'+ str(i)]
        parameters ['A'+ str(i)] = np.tanh(parameters ['Z'+ str(i)])
        A_prev = parameters ['A'+ str(i)]
    
    parameters ['Z'+ str(i+1)] = np.dot(parameters ['W'+ str(i+1)],A_prev) + parameters ['b'+ str(i+1)]
    parameters ['AL'] = np.tanh(parameters ['Z'+ str(i+1)])
#     parameters ['AL'] = parameters.pop('A4') 
    
    if print_para:
        forward_propogation_print_shapes()
            
    return parameters ['AL'] ,parameters

# %%
def forward_propogation_print_shapes():
    print('F_propogated:\n')
    for i in range(1,L):
        print('Z'+str(i),parameters['Z'+str(i)].shape)
        print('W'+str(i),parameters['W'+str(i)].shape)
        print('b'+str(i),parameters['b'+str(i)].shape)
    print('AL',parameters['AL'].shape)
    print('--------------------------------------------')

# %%
layers_dims = [3,5,4,2,1]
L = len(layers_dims)
parameters = initialize_parameters(layers_dims,print_shapes=False)
X = np.random.rand(3,40)
AL,cache = forward_propogation(X,parameters,layers_dims,L)
print(cache)
# Out:
# F_propogated:
#
# Z1 (5, 40)
# W1 (5, 3)
# b1 (5, 1)
# Z2 (4, 40)
# W2 (4, 5)
# b2 (4, 1)
# Z3 (2, 40)
# W3 (2, 4)
# b3 (2, 1)
# Z4 (1, 40)
# W4 (1, 2)
# b4 (1, 1)
# AL (1, 40)
# --------------------------------------------
# {'W1': array([[0.0061016 , 0.00583786, 0.00837724],
#        [0.00992307, 0.00667425, 0.0029099 ],
#        [0.00742136, 0.00706582, 0.00185491],
#        [0.00035621, 0.00294349, 0.00963135],
#        [0.00929076, 0.00878778, 0.00125936]]), 'b1': array([[0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]]), 'W2': array([[0.00303841, 0.00077356, 0.00758768, 0.00308605, 0.0054365 ],
#        [0.00622827, 0.00607974, 0.00173361, 0.00536266, 0.00449906],
#        [0.0070687 , 0.00552633, 0.00816498, 0.00563219, 0.0043992 ],
#        [0.00787768, 0.00402153, 0.00655282, 0.00916052, 0.00983379]]), 'b2': array([[0.],
#        [0.],
#        [0.],
#        [0.]]), 'W3': array([[0.00786682, 0.00096958, 0.00596579, 0.00377489],
#        [0.00794222, 0.0021062 , 0.00595605, 0.00816284]]), 'b3': array([[0.],
#        [0.]]), 'W4': array([[0.00565995, 0.00084906]]), 'b4': array([[0.]]), 'Z1': array([[0.00871254, 0.00932848, 0.00600913, 0.0066911 , 0.0148718 ,
#         0.00904233, 0.00813746, 0.0130342 , 0.0103323 , 0.01600468,
#         0.01109997, 0.01098968, 0.00661668, 0.00939215, 0.01189734,
#         0.00461958, 0.00992503, 0.01259248, 0.01465062, 0.00545182,
#         0.01028843, 0.01273519, 0.00479482, 0.00302756, 0.00908301,
#         0.01009019, 0.01020957, 0.00375461, 0.00765008, 0.00765797,
#         0.01257973, 0.00810266, 0.01196489, 0.00925036, 0.00598104,
#         0.01255326, 0.0082251 , 0.01470567, 0.01196722, 0.015918  ],
#        [0.00897442, 0.00755697, 0.00578146, 0.00548173, 0.01335243,
#         0.00792736, 0.00956587, 0.00968457, 0.01245442, 0.01518529,
#         0.01289473, 0.01251251, 0.00565394, 0.01201769, 0.01379295,
#         0.00568627, 0.0105018 , 0.01479948, 0.0134991 , 0.00409261,
#         0.00998697, 0.009008  , 0.00570178, 0.00211818, 0.00901884,
#         0.00746464, 0.00827482, 0.0048427 , 0.00668744, 0.00891601,
#         0.01323697, 0.00399358, 0.01214664, 0.00719602, 0.0088701 ,
#         0.01073425, 0.01044129, 0.01678952, 0.00964313, 0.01671702],
#        [0.00851115, 0.00591906, 0.0051772 , 0.00457275, 0.01134425,
#         0.00755798, 0.00714827, 0.00851228, 0.0107599 , 0.01302268,
#         0.01124281, 0.00995774, 0.00533131, 0.00972609, 0.01133285,
#         0.00519902, 0.00930033, 0.01211665, 0.01065897, 0.00309372,
#         0.00728574, 0.00798419, 0.00517978, 0.00189471, 0.00837667,
#         4.31924226e-08, 2.76175381e-08, 2.50666046e-08, 3.53985913e-08,
#         3.51267808e-08, 4.79470243e-08, 3.72004692e-08, 3.45392147e-08,
#         1.98403771e-08, 3.16840962e-08, 3.84462050e-08, 1.64568559e-08,
#         3.19636500e-08, 4.08958079e-08, 4.14511158e-08, 1.38665089e-08,
#         2.86110159e-08, 3.40118307e-08, 1.66885836e-08, 8.08352868e-09,
#         2.90998495e-08, 2.70924131e-08, 2.70176693e-08, 1.24379898e-08,
#         2.24394564e-08, 2.44372455e-08, 3.83472830e-08, 1.74409766e-08,
#         3.50787427e-08, 2.44088185e-08, 2.17060165e-08, 3.30242235e-08,
#         2.86952258e-08, 4.84264063e-08, 3.27324663e-08, 4.91587141e-08]]), 'AL': array([[2.87994772e-08, 2.48657500e-08, 1.85606267e-08, 1.84764249e-08,
#         4.31924226e-08, 2.76175381e-08, 2.50666046e-08, 3.53985913e-08,
#         3.51267808e-08, 4.79470243e-08, 3.72004692e-08, 3.45392147e-08,
#         1.98403771e-08, 3.16840962e-08, 3.84462050e-08, 1.64568559e-08,
#         3.19636500e-08, 4.08958079e-08, 4.14511158e-08, 1.38665089e-08,
#         2.86110159e-08, 3.40118307e-08, 1.66885836e-08, 8.08352868e-09,
#         2.90998495e-08, 2.70924131e-08, 2.70176693e-08, 1.24379898e-08,
#         2.24394564e-08, 2.44372455e-08, 3.83472830e-08, 1.74409766e-08,
#         3.50787427e-08, 2.44088185e-08, 2.17060165e-08, 3.30242235e-08,
#         2.86952258e-08, 4.84264063e-08, 3.27324663e-08, 4.91587141e-08]])}

# %%
def compute_cost(Y,AL):
    e=1e-5
    m = Y.shape[1]
    cost = (-1/m)*np.sum(np.multiply(Y,np.log(AL+e),np.multiply(1-Y,np.log(1-AL+e))))
    return(cost)

# %%
# Y = np.random.rand(2,2)
# AL = np.random.rand(2,2)
# cost=compute_cost(Y,AL)
# print(cost)

# %% [markdown]
# $\delta Z = (\frac{-Y}{AL} - \frac{1-Y}{1-AL})\times\sigma\prime(Z)  =  \delta A\times\sigma\prime(Z) $

# %%
def sigmoid_backwards(cache):
    return sigmoid(cache)*(1-sigmoid(cache))
    
def relu_backwards(Z,dA):
    dZ = np.array(dA, copy=True) 
    dZ[Z <= 0] = 0
    return dZ

# %% [markdown]
# $\large\delta A^{[l]} = (\frac{-Y}{AL} - \frac{1-Y}{1-AL})$
#
# $\large\delta Z^{[l]} =  \delta A\times\sigma\prime(Z) $
#
# $\large\delta W^{[l]} =  \frac {1}{m}\delta Z . A^{[l-1]T}$
#
# $\large\delta b^{[l]} = \frac {1}{m}\sum _{i=1}^{m}\delta Z$
#
# $\large\delta A^{[l-1]} = W^{[l]T} . dZ^{[l]}$

# %%
def backpropogation(layers_dims,parameters,AL,Y,X,print_shapes = False):
    caches = {}
    m = Y.shape[1]
    L = len(layers_dims)
    flag = True
    parameters['A' + str(0)] = X
    for l in reversed(range(1,L)):
        
        if (flag) :   
            caches['dAL'] = np.divide(-Y,AL)-np.divide(1-Y,1-AL)                               
            caches['dZ'+ str(l)] = caches['dAL']*sigmoid_backwards(parameters['Z'+ str(l)])    
            caches['dW'+ str(l)] = (1/m)*np.dot(caches['dZ'+ str(l)],parameters['A' + str(l-1)].T)          
            caches['db'+ str(l)] = (1/m)*np.sum(caches['dZ'+ str(l)],axis=1,keepdims=True)     
            caches['dA' + str(l-1)] = np.dot(parameters['W'+ str(l)].T,caches['dZ' + str(l)])
            flag = False
        else:
            caches['dZ'+ str(l)] = caches['dA' + str(l)]*relu_backwards(parameters['Z'+ str(l)],caches['dA'+ str(l)])
            caches['dW'+ str(l)] = (1/m)*np.dot(caches['dZ'+ str(l)],parameters['A' + str(l-1)].T)
            caches['db'+ str(l)] = (1/m)*np.sum(caches['dZ'+ str(l)],axis=1,keepdims=True)
            if (l-1 != 0) :
                caches['dA' + str(l-1)] = np.dot(parameters['W' + str(l)].T,caches['dZ' + str(l)]) 
                
    if print_shapes :
        backpropogation_print_shapes(caches)
    
    return caches

# %%
def backpropogation_print_shapes(caches):
    print('B_propogated:\n')
    print ('dAL',caches['dAL'].shape)
    for l in range(1,L):
        print("dZ"+ str(l),caches['dZ'+ str(l)].shape)
        print("dW"+ str(l),caches['dW'+ str(l)].shape)
        print("db"+ str(l),caches['db'+ str(l)].shape)
        if (l-1 != 0) :
            print('dA' + str(l-1),caches['dA' + str(l-1)].shape)
    print('--------------------------------------------')

# %%
layers_dims = [3,5,4,2,1]
L = len(layers_dims)

# %%
layers_dims = [3,5,4,2,2]
L = len(layers_dims)
parameters = initialize_parameters(layers_dims,print_shapes=True)
X = np.random.rand(3,140)
Y = np.random.rand(1,140)
AL,cache = forward_propogation(X,parameters,layers_dims,print_para = True)
# forward_propogation_print_shapes()
caches = backpropogation(layers_dims,cache,AL,Y,X,print_shapes=True)
# print(caches)
# Out:
# initialised:
#
# W1 (5, 3)
# b1 (5, 1)
# W2 (4, 5)
# b2 (4, 1)
# W3 (2, 4)
# b3 (2, 1)
# W4 (2, 2)
# b4 (2, 1)
# --------------------------------------------
# F_propogated:
#
# Z1 (5, 140)
# W1 (5, 3)
# b1 (5, 1)
# Z2 (4, 140)
# W2 (4, 5)
# b2 (4, 1)
# Z3 (2, 140)
# W3 (2, 4)
# b3 (2, 1)
# Z4 (2, 140)
# W4 (2, 2)
# b4 (2, 1)
# AL (2, 140)
# --------------------------------------------
# B_propogated:
#
# dAL (2, 140)
# dZ1 (5, 140)
# dW1 (5, 3)
# db1 (5, 1)
# dZ2 (4, 140)
# dW2 (4, 5)
# db2 (4, 1)
# dA1 (5, 140)
# dZ3 (2, 140)
# dW3 (2, 4)
# db3 (2, 1)
# dA2 (4, 140)
# dZ4 (2, 140)
# dW4 (2, 2)
# db4 (2, 1)
# dA3 (2, 140)
# --------------------------------------------

# %% [markdown]
# $$ W^{[l]} = W^{[l]} - \alpha \text{ } dW^{[l]} \tag{16}$$
# $$ b^{[l]} = b^{[l]} - \alpha \text{ } db^{[l]} \tag{17}$$

# %%
def update_parameters(parameters,caches,alpha,L):
    for l in range(L-1):
        parameters['W'+ str(l+1)] = parameters['W'+ str(l+1)] - alpha * caches['dW'+ str(l+1)]
        parameters['b'+ str(l+1)] = parameters['b'+ str(l+1)] - alpha * caches['db'+ str(l+1)]
    return parameters

# %%
cache_updated = update_parameters(cache,caches,0.01,L)
# print(cache_updated)

# %%
def predict(X, Y, parameters,layers_dims):
    m = X.shape[1]
    n = len(layers_dims)  
#     p = np.zeros(Y.shape)
    AL, caches = forward_propogation(X, parameters,layers_dims)
    
#     _max = AL[0][0]  
#     for i in range(0, AL.shape[1]):
#         for j in range(0,AL.shape[0]):
#             if (AL[i][j] > _max):
#                 p, _max = j,AL[i][j]
#         for k in range(0,AL.shape[0]):   
#             if (k == p) :
#                 AL[i][k] = 1
#             else :
#                 AL[i][k] = 0
    for i in range(AL.shape[1]):
        _max = AL[:,i].argmax()
        AL[_max,i] = 1
        for j in range(AL.shape[0]):
            if AL[j,i] != 1 :
                AL[j,i] = 0
            
    print("Accuracy: "  + str(np.sum((AL == Y)/m)*100))
        
    return AL

# %%
def nn( X, Y, layers_dims, iterations,alpha, print_cost= False):
    parameters = initialize_parameters(layers_dims, print_shapes = False)
    costs = []
    for i in range(1,iterations):
        
        AL ,caches = forward_propogation(X,parameters,layers_dims)
        cost = compute_cost(Y,AL)
        caches = backpropogation(layers_dims,parameters,AL,Y,X,print_shapes = False)
        parameters = update_parameters(parameters,caches,alpha,len(layers_dims))
        
        if print_cost and i % 100 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))
        if print_cost and i % 100 == 0:
            costs.append(cost)
    p = predict(X, Y, parameters,layers_dims)
    return p

# %% [markdown]
# # Training and Testing the nn

# %%
layers_dims = [X_train.shape[0],5,4,2,Y_train.shape[0]]
p = nn( X_train, Y_train, layers_dims, 1500,0.01, print_cost= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-c910fa05664b> in <module>
#       1 layers_dims = [X_train.shape[0],5,4,2,Y_train.shape[0]]
# ----> 2 p = nn( X_train, Y_train, layers_dims, 1500,0.01, print_cost= True)
#
# <ipython-input-80-5d860b7bc78f> in nn(X, Y, layers_dims, iterations, alpha, print_cost)
#       4     for i in range(1,iterations):
#       5
# ----> 6         AL ,caches = forward_propogation(X,parameters,layers_dims)
#       7         cost = compute_cost(Y,AL)
#       8         caches = backpropogation(layers_dims,parameters,AL,Y,X,print_shapes = False)
#
# <ipython-input-106-58e90242e576> in forward_propogation(X, parameters, layers_dims, print_para)
#       5
#       6     for i in range(1,L+1):
# ----> 7         parameters ['Z'+ str(i)] = np.dot(parameters ['W'+ str(i)],A_prev) + parameters ['b'+ str(i)]
#       8         if i == L:
#       9             parameters ['AL'] = np.tanh(parameters ['Z'+ str(i)])
#
# KeyError: 'W5'
